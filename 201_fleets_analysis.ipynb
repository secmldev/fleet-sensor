# %% [markdown]
# ### Objective
# - Get one fleet and one unit data
# - utilize the plot functionality for different plots

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
DATASET_NAMES = ['FD001', 'FD002', 'FD003', 'FD004']

# %%
train = pd.read_csv('data/train.csv')
train.head()
# Out:
#    unit  time_cycles  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 0     1            1       -0.0007       -0.0004         100.0    518.67
# 1     1            2        0.0019       -0.0003         100.0    518.67
# 2     1            3       -0.0043        0.0003         100.0    518.67
# 3     1            4        0.0007        0.0000         100.0    518.67
# 4     1            5       -0.0019       -0.0002         100.0    518.67
#
#    sensor_2  sensor_3  sensor_4  sensor_5  ...  sensor_13  sensor_14  \
# 0    641.82   1589.70   1400.60     14.62  ...    2388.02    8138.62
# 1    642.15   1591.82   1403.14     14.62  ...    2388.07    8131.49
# 2    642.35   1587.99   1404.20     14.62  ...    2388.03    8133.23
# 3    642.35   1582.79   1401.87     14.62  ...    2388.08    8133.83
# 4    642.37   1582.85   1406.22     14.62  ...    2388.04    8133.80
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  \
# ...

# %%
col_names = train.columns
col_names
# Out:
# Index(['unit', 'time_cycles', 'op_setting_1', 'op_setting_2', 'op_setting_3',
#        'sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5', 'sensor_6',
#        'sensor_7', 'sensor_8', 'sensor_9', 'sensor_10', 'sensor_11',
#        'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16',
#        'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21',
#        'dataset'],
#       dtype='object')

# %%
OP_SETTING_COLUMNS = ['op_setting_1', 'op_setting_2', 'op_setting_3']

# %%
SENSOR_COLUMNS = ['sensor_1', 'sensor_2', 'sensor_3', 'sensor_4', 'sensor_5', 'sensor_6',
       'sensor_7', 'sensor_8', 'sensor_9', 'sensor_10', 'sensor_11',
       'sensor_12', 'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16',
       'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21']

# %% [markdown]
# ### Import utils for plotting

# %%
from utils.plot import plot_all_units_per_dataset, plot_all_units, plot_unit_sensors_ts

# %%
# plot_all_units_per_dataset(train)

# %% [markdown]
# ### Plot for single fleet engine at at time

# %%
# plot_all_units(train, DATASET_NAMES[0], columns=SENSOR_COLUMNS)

# %% [markdown]
# # Plot unit and sensors data

# %%
plot_unit_sensors_ts(unit=1, df=train, features=SENSOR_COLUMNS, dataset_name=DATASET_NAMES[0], per_sensor=True)

# %% [markdown]
# ### Analyze data for unit and sensor

# %%
df = train

# %%
unit_df = df[(df['unit'] == 1) & (df['dataset'] == 'FD001')]
unit_df
# Out:
#      unit  time_cycles  op_setting_1  op_setting_2  op_setting_3  sensor_1  \
# 0       1            1       -0.0007       -0.0004         100.0    518.67
# 1       1            2        0.0019       -0.0003         100.0    518.67
# 2       1            3       -0.0043        0.0003         100.0    518.67
# 3       1            4        0.0007        0.0000         100.0    518.67
# 4       1            5       -0.0019       -0.0002         100.0    518.67
# ..    ...          ...           ...           ...           ...       ...
# 187     1          188       -0.0067        0.0003         100.0    518.67
# 188     1          189       -0.0006        0.0002         100.0    518.67
# 189     1          190       -0.0027        0.0001         100.0    518.67
# 190     1          191       -0.0000       -0.0004         100.0    518.67
# 191     1          192        0.0009       -0.0000         100.0    518.67
#
# ...

# %%
unit_df.to_csv('data/FD001_unit1.csv', index=False)

# %%
type(unit_df)
# Out:
# pandas.core.frame.DataFrame

# %%
unit_sensor_df = unit_df[['sensor_2']]
unit_sensor_df
# Out:
#      sensor_2
# 0      641.82
# 1      642.15
# 2      642.35
# 3      642.35
# 4      642.37
# ..        ...
# 187    643.75
# 188    644.18
# 189    643.64
# 190    643.34
# 191    643.54
#
# [192 rows x 1 columns]

# %%
type(unit_sensor_df)
# Out:
# pandas.core.frame.DataFrame
